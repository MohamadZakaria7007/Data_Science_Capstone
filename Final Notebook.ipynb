# %% [markdown]
# <h1>Welcome to my final capstone project notebook!</h1>

# %% [markdown]
# <h3>Contents of this notebook:</h3>

# %% [markdown]
# <ul>
#     <li>Intro to the project.</li>
#     <li>Target audience.</li>
#     <li>Importing libraries.</li>
#     <li>Extracting tata into a data frame</li>
#     <li>Finding the latitude and longitude of each zip code</li>
#     <li>Analyze each post office in category.</li>
#     <li>List and display the top 5 existing facilities for each Pin Code</li>
#     <li>Visualization</li>
#     <li>What are the best locations in Mumbai as per infrastructure?</li>
#     <li>Which all areas lack the infrastructure facilities?</li>
#     <li>Potential area for the development of infrastructure</li>
#     <li>Best places to stay within.</li>
#     <li>Clustering the dataset.</li>
#     <li>Another round of visualization.</li>
#     <li>Clusters results.</li>
#     <li>Observations.</li>
#     <li>Acknowledgments.</li>
#     <li>Links to other assets of the project.</li>
# </ul>

# %% [markdown]
# <h3>Intro to the project:</h3>

# %% [markdown]
# Mumbai is busy, Mumbai is chaotic, Mumbai is loud. Also called the ‘Maximum City’, Mumbai throbs with a harsh, edgy energy. There is absolutely no sense of personal space, yet it gives you the space to be yourself.
#
# 21.5 million people call the greater Mumbai metropolitan area, their home.  With over 25,000 people per square kilometer it is one of the most densely populated spaces in the world. Asia’s largest slum, Dharavi, packs over 300,000 people per square kilometer. Mumbai is also one of the wealthiest cities in India, accounting for 25% of industrial output and over 70% of maritime trade. The city is a financial, money making, and showbiz capital of India. ‘Bollywood’ the heart of the Indian film industry is firmly anchored in Mumbai. Most of India’s major television networks and publishing houses are located here as well.
#
# This concentration of cultural and financial institutions attracts migrants from all over the country and creates a high level of diversity. It is a city of dreams for some, but a tough life on unforgiving streets for many others. No wonder BBC calls Mumbai the most cosmopolitan city on the subcontinent. In the cosmopolitan chaos of this modern city is a community that thrives. Call them Mumbaikars or Bombayites – they live in a unique ecosystem not found. All these facts make Mumbai a very interesting place for this project.

# %% [markdown]
# <h3>Target audience:</h3>

# %% [markdown]
# This project aims to help 2 types of people:
#
# Normal individuals who are looking for places with specific facilities in mind (for example, someone who likes to eat outside would search for places with many restaurants in a tight radius).
#
# Investors who would like to build new facilities in the city and looking for good potential locations to do so (for example, someone who would like to build a hotel would most likely avoid building it near other hotels to avoid competition).

# %% [markdown]
# <h3>Importing libraries:</h3>

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd
import folium
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# !conda install -c conda-forge lxml --yes
import requests
import lxml.html as lh
from sklearn.cluster import KMeans
print("Libraries imported.")
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
clean_df = pd.read_csv('mumbailatlong.csv',index_col='Unnamed: 0')
clean_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-529b227ccad1> in <module>
# ----> 1 clean_df = pd.read_csv('mumbailatlong.csv',index_col='Unnamed: 0')
#       2 clean_df.head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# <h3>Extracting tata into a data frame:</h3>

# %%
url='https://mumbai7.com/postal-codes-in-mumbai/'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')
r = requests.get(url)

#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))

size_of_col = 3
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 4, the //tr data is not from our table 
    if len(T)!=size_of_col:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1
        
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-41394b644100> in <module>
#       1 url='https://mumbai7.com/postal-codes-in-mumbai/'
#       2 #Create a handle, page, to handle the contents of the website
# ----> 3 page = requests.get(url)
#       4 #Store the contents of the website under doc
#       5 doc = lh.fromstring(page.content)
#
# NameError: name 'requests' is not defined

# %% [markdown]
# <h3>Finding the latitude and longitude of each zip code:</h3>

# %%
df["Latitude"] = ""
df["Longitude"] = ""
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-775b1ee92449> in <module>
# ----> 1 df["Latitude"] = ""
#       2 df["Longitude"] = ""
#       3 df.shape
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df1 = df.loc[0:25]
df2 = df.loc[26:50]
df3 = df.loc[51:75]
df4 = df.loc[76:100]
df5 = df.loc[101:125]
df6 = df.loc[126:150]
df7 = df.loc[151:156]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7bf002441cb1> in <module>
# ----> 1 df1 = df.loc[0:25]
#       2 df2 = df.loc[26:50]
#       3 df3 = df.loc[51:75]
#       4 df4 = df.loc[76:100]
#       5 df5 = df.loc[101:125]
#
# NameError: name 'df' is not defined

# %%
to_drop_unknown = []
geolocator = Nominatim(user_agent="ny_explorer")
for index, row in df1.iterrows():
    address = row['Post Office'] + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df1.loc[index, 'Latitude'] = latitude
        df1.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bf117e9e9cb2> in <module>
#       1 to_drop_unknown = []
# ----> 2 geolocator = Nominatim(user_agent="ny_explorer")
#       3 for index, row in df1.iterrows():
#       4     address = row['Post Office'] + ', Mumbai'
#       5     try:
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer2")
for index, row in df2.iterrows():
    address = row['Post Office'] + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df2.loc[index, 'Latitude'] = latitude
        df2.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cb5fee048631> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer2")
#       2 for index, row in df2.iterrows():
#       3     address = row['Post Office'] + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer3")
for index, row in df3.iterrows():
    address = row['Post Office'] + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df3.loc[index, 'Latitude'] = latitude
        df3.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9678ba98affb> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer3")
#       2 for index, row in df3.iterrows():
#       3     address = row['Post Office'] + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer4")
for index, row in df4.iterrows():
    address = row['Post Office'] + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df4.loc[index, 'Latitude'] = latitude
        df4.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6cb240a2981a> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer4")
#       2 for index, row in df4.iterrows():
#       3     address = row['Post Office'] + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer5")
for index, row in df5.iterrows():
    address = row['Post Office'] + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df5.loc[index, 'Latitude'] = latitude
        df5.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e87582b68534> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer5")
#       2 for index, row in df5.iterrows():
#       3     address = row['Post Office'] + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer6")
for index, row in df6.iterrows():
    address = row['Post Office'] + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df6.loc[index, 'Latitude'] = latitude
        df6.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c2ebfaf11b67> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer6")
#       2 for index, row in df6.iterrows():
#       3     address = row['Post Office'] + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer7")
for index, row in df7.iterrows():
    address = row['Post Office'] + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df7.loc[index, 'Latitude'] = latitude
        df7.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6f7343c53df6> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer7")
#       2 for index, row in df7.iterrows():
#       3     address = row['Post Office'] + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
print(to_drop_unknown)
# Out:
# []

# %%
dfa = dfa.append(df3, ignore_index = True)
dfa = dfa.append(df4, ignore_index = True)
dfa = dfa.append(df5, ignore_index = True)
dfa = dfa.append(df6, ignore_index = True)
dfa = dfa.append(df7, ignore_index = True)
cleandf = dfa.drop(to_drop_unknown)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1e06adc6f417> in <module>
# ----> 1 dfa = dfa.append(df3, ignore_index = True)
#       2 dfa = dfa.append(df4, ignore_index = True)
#       3 dfa = dfa.append(df5, ignore_index = True)
#       4 dfa = dfa.append(df6, ignore_index = True)
#       5 dfa = dfa.append(df7, ignore_index = True)
#
# NameError: name 'dfa' is not defined

# %%
cleandf.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9f1f1ad7574a> in <module>
# ----> 1 cleandf.shape
#
# NameError: name 'cleandf' is not defined

# %%
tosearch_df = df.loc[to_drop_unknown]
tosearch_df.head()
tosearch_df.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3519436b0ddc> in <module>
# ----> 1 tosearch_df = df.loc[to_drop_unknown]
#       2 tosearch_df.head()
#       3 tosearch_df.reset_index(drop=True)
#
# NameError: name 'df' is not defined

# %%
tosearch_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9e2ad062f2ea> in <module>
# ----> 1 tosearch_df.shape
#
# NameError: name 'tosearch_df' is not defined

# %%
tosearch_df1 = tosearch_df.iloc[0:25]
tosearch_df2 = tosearch_df.iloc[26:50]
tosearch_df3 = tosearch_df.iloc[51:55]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-257ec21512b7> in <module>
# ----> 1 tosearch_df1 = tosearch_df.iloc[0:25]
#       2 tosearch_df2 = tosearch_df.iloc[26:50]
#       3 tosearch_df3 = tosearch_df.iloc[51:55]
#
# NameError: name 'tosearch_df' is not defined

# %%
to_drop_unknown2 = []
geolocator = Nominatim(user_agent="ny_explorer8")
for index, row in tosearch_df1.iterrows():
    address = str(row['Pin Code']) + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        tosearch_df1.loc[index, 'Latitude'] = latitude
        tosearch_df1.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown2.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-24d4d0f3ae37> in <module>
#       1 to_drop_unknown2 = []
# ----> 2 geolocator = Nominatim(user_agent="ny_explorer8")
#       3 for index, row in tosearch_df1.iterrows():
#       4     address = str(row['Pin Code']) + ', Mumbai'
#       5     try:
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer9")
for index, row in tosearch_df2.iterrows():
    address = str(row['Pin Code']) + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        tosearch_df2.loc[index, 'Latitude'] = latitude
        tosearch_df2.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown2.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a6329adb7e5e> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer9")
#       2 for index, row in tosearch_df2.iterrows():
#       3     address = str(row['Pin Code']) + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
geolocator = Nominatim(user_agent="ny_explorer10")
for index, row in tosearch_df3.iterrows():
    address = str(row['Pin Code']) + ', Mumbai'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        tosearch_df3.loc[index, 'Latitude'] = latitude
        tosearch_df3.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown2.append(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c043d421f090> in <module>
# ----> 1 geolocator = Nominatim(user_agent="ny_explorer10")
#       2 for index, row in tosearch_df3.iterrows():
#       3     address = str(row['Pin Code']) + ', Mumbai'
#       4     try:
#       5         location = geolocator.geocode(address)
#
# NameError: name 'Nominatim' is not defined

# %%
print(to_drop_unknown2)
# Out:
# []

# %%
dfb = tosearch_df1.append(tosearch_df2, ignore_index = True)
dfb = dfb.append(tosearch_df3, ignore_index = True)
dfb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-fdf868b56247> in <module>
# ----> 1 dfb = tosearch_df1.append(tosearch_df2, ignore_index = True)
#       2 dfb = dfb.append(tosearch_df3, ignore_index = True)
#       3 dfb
#
# NameError: name 'tosearch_df1' is not defined

# %%
dfb['Latitude'].replace('', np.nan, inplace=True)
dfb.dropna(subset=['Latitude'], inplace=True)
dfb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6baa934c8df8> in <module>
# ----> 1 dfb['Latitude'].replace('', np.nan, inplace=True)
#       2 dfb.dropna(subset=['Latitude'], inplace=True)
#       3 dfb
#
# NameError: name 'dfb' is not defined

# %%
lst = [['Mumbai','B A R C',400085,19.0167,72.85 ],['Thane','Talasari',401606,19.9167,73.2333],['Navi Mumbai','NAD Karanja',400704,19.0778,72.8944,],['Thane','Jawhar',401603,19.9167,73.2333]]
dfc = pd.DataFrame(list(lst),  columns =['City','Post Office','Pin Code','Latitude','Longitude']) 
dfc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b4e719560088> in <module>
#       1 lst = [['Mumbai','B A R C',400085,19.0167,72.85 ],['Thane','Talasari',401606,19.9167,73.2333],['Navi Mumbai','NAD Karanja',400704,19.0778,72.8944,],['Thane','Jawhar',401603,19.9167,73.2333]]
# ----> 2 dfc = pd.DataFrame(list(lst),  columns =['City','Post Office','Pin Code','Latitude','Longitude'])
#       3 dfc
#
# NameError: name 'pd' is not defined

# %%
clean_df2 = dfb.append(dfc, ignore_index = True)
clean_df2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-55a9d9251cbf> in <module>
# ----> 1 clean_df2 = dfb.append(dfc, ignore_index = True)
#       2 clean_df2.shape
#
# NameError: name 'dfb' is not defined

# %%
clean_df = cleandf.append(clean_df2, ignore_index = True)
clean_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-5caaa6b7608f> in <module>
# ----> 1 clean_df = cleandf.append(clean_df2, ignore_index = True)
#       2 clean_df.shape
#
# NameError: name 'cleandf' is not defined

# %%
clean_df.to_csv('mumbailatlong.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c2984d96c47d> in <module>
# ----> 1 clean_df.to_csv('mumbailatlong.csv')
#
# NameError: name 'clean_df' is not defined

# %%
CLIENT_ID = 'NT2C1SLVDXCSGCZPWP3D0JM41SNOZMB5F4IYCL5CR2V20ZIP' # your Foursquare ID
CLIENT_SECRET = 'PS1QM5EW1EVJPXYJK4JF45GJHMHZJBCDZAD4CXQJUMIDC4NM' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
clean_df_new = clean_df.copy()
# Out:
# Your credentails:
# CLIENT_ID: NT2C1SLVDXCSGCZPWP3D0JM41SNOZMB5F4IYCL5CR2V20ZIP
# CLIENT_SECRET:PS1QM5EW1EVJPXYJK4JF45GJHMHZJBCDZAD4CXQJUMIDC4NM
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1faf4f4029a0> in <module>
#       6 print('CLIENT_ID: ' + CLIENT_ID)
#       7 print('CLIENT_SECRET:' + CLIENT_SECRET)
# ----> 8 clean_df_new = clean_df.copy()
#
# NameError: name 'clean_df' is not defined

# %%
venues_df = pd.read_csv('mumbaiexplore.csv',index_col='Unnamed: 0')
venues_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0281e1752942> in <module>
# ----> 1 venues_df = pd.read_csv('mumbaiexplore.csv',index_col='Unnamed: 0')
#       2 venues_df.head()
#
# NameError: name 'pd' is not defined

# %%
radius = 600
LIMIT = 225
venues = []

for lat, long, pin, post, city in zip(clean_df_new['Latitude'], clean_df_new['Longitude'], clean_df_new['Pin Code'], clean_df_new['Post Office'], clean_df_new['City']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,        CLIENT_SECRET,        VERSION,        lat,        long,        radius,         LIMIT)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for venue in results:
        venues.append((
            post,            pin,            lat,             long,          city,
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))
        venues_df = pd.DataFrame(venues)
        venues_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-188ac9375900> in <module>
#       3 venues = []
#       4
# ----> 5 for lat, long, pin, post, city in zip(clean_df_new['Latitude'], clean_df_new['Longitude'], clean_df_new['Pin Code'], clean_df_new['Post Office'], clean_df_new['City']):
#       6     url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
#       7         CLIENT_ID,        CLIENT_SECRET,        VERSION,        lat,        long,        radius,         LIMIT)
#
# NameError: name 'clean_df_new' is not defined

# %%
venues_df.columns = ['Post Office', 'Pin Code', 'Latitude', 'Longitude', 'City', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']

print(venues_df.shape)
venues_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-35bf6f0f2733> in <module>
# ----> 1 venues_df.columns = ['Post Office', 'Pin Code', 'Latitude', 'Longitude', 'City', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
#       2
#       3 print(venues_df.shape)
#       4 venues_df.head()
#
# NameError: name 'venues_df' is not defined

# %%
venues_df.to_csv('mumbaiexplore.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b33078fcf88e> in <module>
# ----> 1 venues_df.to_csv('mumbaiexplore.csv')
#
# NameError: name 'venues_df' is not defined

# %%
venues_df.groupby(['Post Office', 'Pin Code', 'City']).count().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-52dcf9fd461c> in <module>
# ----> 1 venues_df.groupby(['Post Office', 'Pin Code', 'City']).count().head()
#
# NameError: name 'venues_df' is not defined

# %%
print('There are {} uniques categories.'.format(len(venues_df['VenueCategory'].unique())))

# %%
venues_df['VenueCategory'].unique()[:20]

# %% [markdown]
# <h3>Analyze each post office in category:</h3>

# %%
mumbai_onehot = pd.get_dummies(venues_df[['VenueCategory']], prefix="", prefix_sep="")

# add postal, borough and neighborhood column back to dataframe
mumbai_onehot['Post Office'] = venues_df['Post Office'] 
mumbai_onehot['Pin Code'] = venues_df['Pin Code'] 
mumbai_onehot['City'] = venues_df['City'] 

# move postal, borough and neighborhood column to the first column
fixed_columns = list(mumbai_onehot.columns[-3:]) + list(mumbai_onehot.columns[:-3])
mumbai_onehot = mumbai_onehot[fixed_columns]

print(mumbai_onehot.shape)
mumbai_onehot.head()

# %%
mumbai_grouped = mumbai_onehot.groupby(["Post Office", "Pin Code", "City"]).mean().reset_index()

print(mumbai_grouped.shape)
mumbai_grouped.head()

# %% [markdown]
# <h3>List and display the top 5 existing facilities for each Pin Code:</h3>

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
areaColumns = ["Post Office", "Pin Code", "City"]
freqColumns = []
for ind in np.arange(num_top_venues):
    try:
        freqColumns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        freqColumns.append('{}th Most Common Venue'.format(ind+1))
columns = areaColumns+freqColumns

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Post Office'] = mumbai_grouped['Post Office']
neighborhoods_venues_sorted['Pin Code'] = mumbai_grouped['Pin Code']
neighborhoods_venues_sorted['City'] = mumbai_grouped['City']

for ind in np.arange(mumbai_grouped.shape[0]):
    row_categories = mumbai_grouped.iloc[ind, :].iloc[3:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    neighborhoods_venues_sorted.iloc[ind, 3:] = row_categories_sorted.index.values[0:num_top_venues]

# neighborhoods_venues_sorted.sort_values(freqColumns, inplace=True)
print(neighborhoods_venues_sorted.shape)
neighborhoods_venues_sorted.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-439281ac7739> in <module>
#       6 areaColumns = ["Post Office", "Pin Code", "City"]
#       7 freqColumns = []
# ----> 8 for ind in np.arange(num_top_venues):
#       9     try:
#      10         freqColumns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
#
# NameError: name 'np' is not defined

# %%
address = 'Mumbai'
latitude = 19.0760
longitude = 72.8777
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geograpical coordinate of Mumbai are 19.076, 72.8777.

# %%
mumbai_merged = clean_df.copy()
mumbai_merged = mumbai_merged.join(neighborhoods_venues_sorted[["Pin Code", "1st Most Common Venue"]].set_index("Pin Code"), on="Pin Code")
print(mumbai_merged.shape)
mumbai_merged.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-71430caff479> in <module>
# ----> 1 mumbai_merged = clean_df.copy()
#       2 mumbai_merged = mumbai_merged.join(neighborhoods_venues_sorted[["Pin Code", "1st Most Common Venue"]].set_index("Pin Code"), on="Pin Code")
#       3 print(mumbai_merged.shape)
#       4 mumbai_merged.head()
#
# NameError: name 'clean_df' is not defined

# %% [markdown]
# <h3>Visualization:</h3>

# %%
import folium
my_map = folium.Map(location=[latitude, longitude], zoom_start=11)
# add markers to map
for lat, lng, label1,common in zip(mumbai_merged['Latitude'], mumbai_merged['Longitude'], mumbai_merged['Post Office'],mumbai_merged['1st Most Common Venue'] ):
    labelnew =  'Post office : {} , Top Existing Infrastructure  : {}'.format(label1,common)
    label = folium.Popup( labelnew, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(my_map)  
my_map
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-61942c3fbac8> in <module>
# ----> 1 import folium
#       2 my_map = folium.Map(location=[latitude, longitude], zoom_start=11)
#       3 # add markers to map
#       4 for lat, lng, label1,common in zip(mumbai_merged['Latitude'], mumbai_merged['Longitude'], mumbai_merged['Post Office'],mumbai_merged['1st Most Common Venue'] ):
#       5     labelnew =  'Post office : {} , Top Existing Infrastructure  : {}'.format(label1,common)
#
# ModuleNotFoundError: No module named 'folium'

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://raw.githubusercontent.com/RohitLearner/IBM-Applied-D.S-Capstone-Project/master/Week%205/Results/Result_9.png")
# Out:
# <img src="https://raw.githubusercontent.com/RohitLearner/IBM-Applied-D.S-Capstone-Project/master/Week%205/Results/Result_9.png"/>

# %%
venues_df['VenueCategory'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-15ea62ab4c27> in <module>
# ----> 1 venues_df['VenueCategory'].unique()
#
# NameError: name 'venues_df' is not defined

# %%
search_query= ['Restaurant', 'Hotel', 'Farmers Market', 'Shopping Mall', 'Gym / Fitness Center', 'Pharmacy',
                         'Electronics Store', 'Indie Movie Theater', 'Light Rail Station','Metro Station', 'Train','Train Station', 'Garden',
                          'Theater','ATM', 'Office', 'Bus Station', 'Bank', 'Market' , 'Business Service', 'Monument / Landmark' ,
                          'Resort', 'Hospital', 'Police Station', 'School', 'College', 'Café' , 'Park', 'Playground',
                'Convention Center', 'College Auditorium', 'Government Building', 'Airport Terminal',
                         ]
print(len(search_query))
# Out:
# 33

# %%
quality_dataframe = []
quality_dataframe= venues_df.loc[venues_df['VenueCategory'].isin(search_query)]
quality_dataframe.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-416fa2b09b57> in <module>
#       1 quality_dataframe = []
# ----> 2 quality_dataframe= venues_df.loc[venues_df['VenueCategory'].isin(search_query)]
#       3 quality_dataframe.shape
#
# NameError: name 'venues_df' is not defined

# %%
quality_dataframe
# Out:
# []

# %%
qualitymumbai_onehot = pd.get_dummies(quality_dataframe[['VenueCategory']], prefix="", prefix_sep="")
# add postal, borough and neighborhood column back to dataframe
qualitymumbai_onehot['Post Office'] = quality_dataframe['Post Office'] 
qualitymumbai_onehot['Pin Code'] = quality_dataframe['Pin Code'] 
qualitymumbai_onehot['City'] = quality_dataframe['City'] 

# move postal, borough and neighborhood column to the first column
fixed_columns = list(qualitymumbai_onehot.columns[-3:]) + list(qualitymumbai_onehot.columns[:-3])
qualitymumbai_onehot = qualitymumbai_onehot[fixed_columns]

print(qualitymumbai_onehot.shape)
qualitymumbai_onehot.head()
print(qualitymumbai_onehot.columns.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-f77e1c216182> in <module>
# ----> 1 qualitymumbai_onehot = pd.get_dummies(quality_dataframe[['VenueCategory']], prefix="", prefix_sep="")
#       2 # add postal, borough and neighborhood column back to dataframe
#       3 qualitymumbai_onehot['Post Office'] = quality_dataframe['Post Office']
#       4 qualitymumbai_onehot['Pin Code'] = quality_dataframe['Pin Code']
#       5 qualitymumbai_onehot['City'] = quality_dataframe['City']
#
# NameError: name 'pd' is not defined

# %%
qualitymumbai_grouped = qualitymumbai_onehot.groupby(["Post Office", "Pin Code", "City"]).sum().reset_index()
print(qualitymumbai_grouped.shape)
qualitymumbai_grouped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-213f7286adc8> in <module>
# ----> 1 qualitymumbai_grouped = qualitymumbai_onehot.groupby(["Post Office", "Pin Code", "City"]).sum().reset_index()
#       2 print(qualitymumbai_grouped.shape)
#       3 qualitymumbai_grouped.head()
#
# NameError: name 'qualitymumbai_onehot' is not defined

# %%
qualitymumbai_grouped['Total infrastructure'] =  qualitymumbai_grouped[qualitymumbai_grouped.drop(['Post Office','Pin Code','City'], axis=1).columns.values].sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5b6ba5aefa55> in <module>
# ----> 1 qualitymumbai_grouped['Total infrastructure'] =  qualitymumbai_grouped[qualitymumbai_grouped.drop(['Post Office','Pin Code','City'], axis=1).columns.values].sum(axis=1)
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %%
qualitymumbai_grouped.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-92093892dae2> in <module>
# ----> 1 qualitymumbai_grouped.shape
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %% [markdown]
# <h3>What are the best locations in Mumbai as per infrastructure?</h3>

# %%
qualitymumbai_grouped[qualitymumbai_grouped['Total infrastructure'] == qualitymumbai_grouped['Total infrastructure'].max()].transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-15aead187921> in <module>
# ----> 1 qualitymumbai_grouped[qualitymumbai_grouped['Total infrastructure'] == qualitymumbai_grouped['Total infrastructure'].max()].transpose()
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %% [markdown]
# <h3>Which all areas lack the infrastructure facilities?</h3>

# %%
badquality = qualitymumbai_grouped[qualitymumbai_grouped['Total infrastructure'] == qualitymumbai_grouped['Total infrastructure'].min()]
badquality
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-0677ca72deeb> in <module>
# ----> 1 badquality = qualitymumbai_grouped[qualitymumbai_grouped['Total infrastructure'] == qualitymumbai_grouped['Total infrastructure'].min()]
#       2 badquality
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %% [markdown]
# <h3>Potential area for the development of infrastructure</h3>

# %%
yourchoiceinfra = 'Restaurant' # Select your choice of infrastructue from VenueCategory
badqualitychoice = qualitymumbai_grouped[qualitymumbai_grouped[yourchoiceinfra] == qualitymumbai_grouped[yourchoiceinfra].min()]
badqualitychoice['Post Office']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-ee33225a495b> in <module>
#       1 yourchoiceinfra = 'Restaurant' # Select your choice of infrastructue from VenueCategory
# ----> 2 badqualitychoice = qualitymumbai_grouped[qualitymumbai_grouped[yourchoiceinfra] == qualitymumbai_grouped[yourchoiceinfra].min()]
#       3 badqualitychoice['Post Office']
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %%
yourchoicearea = 'Mantralaya'   # Change with the name of postal area where you want to see potential
infraqualitychoice = qualitymumbai_grouped[qualitymumbai_grouped['Post Office'] == yourchoicearea].transpose()
infraqualitychoice = infraqualitychoice.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-431344f1a69c> in <module>
#       1 yourchoicearea = 'Mantralaya'   # Change with the name of postal area where you want to see potential
# ----> 2 infraqualitychoice = qualitymumbai_grouped[qualitymumbai_grouped['Post Office'] == yourchoicearea].transpose()
#       3 infraqualitychoice = infraqualitychoice.reset_index()
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %%
print("These are infrastructures with highest potential in" , yourchoicearea, "area : " )
for i in range(len(infraqualitychoice)) : 
    if (infraqualitychoice.iloc[i, 1] == 0):
        print(infraqualitychoice.iloc[i, 0])
# Out:
# These are infrastructures with highest potential in Mantralaya area :
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-b602e9f117f3> in <module>
#       1 print("These are infrastructures with highest potential in" , yourchoicearea, "area : " )
# ----> 2 for i in range(len(infraqualitychoice)) :
#       3     if (infraqualitychoice.iloc[i, 1] == 0):
#       4         print(infraqualitychoice.iloc[i, 0])
#
# NameError: name 'infraqualitychoice' is not defined

# %%
from pandas.io.json import json_normalize
search_query = 'School'
LIMIT = 5
radius = 500
latitude = 19.016700   # Latitude of your choice postal office from 
longitude = 72.850000  # Longitude of your choice postal office from 
VERSION = 20180604
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-90bc8b88cba6> in <module>
#       7 VERSION = 20180604
#       8 url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
# ----> 9 results = requests.get(url).json()
#      10 results
#
# NameError: name 'requests' is not defined

# %%
venues = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(venues)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-68e5d9f4d041> in <module>
# ----> 1 venues = results['response']['venues']
#       2 # tranform venues into a dataframe
#       3 dataframe = json_normalize(venues)
#
# NameError: name 'results' is not defined

# %%
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-2e3fce470734> in <module>
# ----> 1 clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
#       2 clean_dataframe = dataframe.loc[:,clean_columns]
#       3
#       4 # function that extracts the category of the venue
#       5 def get_category_type(row):
#
# NameError: name 'dataframe' is not defined

# %% [markdown]
# <h3>Best places to stay within:</h3>

# %%
quality_infra_mumbai2 = pd.read_csv('https://github.com/RohitLearner/IBM-Applied-D.S-Capstone-Project/blob/master/Week%205/Final%20.ipynb%20files/essentialinfra.csv',index_col='Unnamed: 0')
quality_infra_mumbai2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-fb132b70bebc> in <module>
# ----> 1 quality_infra_mumbai2 = pd.read_csv('https://github.com/RohitLearner/IBM-Applied-D.S-Capstone-Project/blob/master/Week%205/Final%20.ipynb%20files/essentialinfra.csv',index_col='Unnamed: 0')
#       2 quality_infra_mumbai2.head()
#
# NameError: name 'pd' is not defined

# %%
 
                         'Metro Station', 'Train Station', 'ATM', 'Office', 'Bus Station', 'Bank', 'Market' ,
                          'Police Station', 'School', 'College & University', 'Park'
 ]
categoryId = ['4bf58dd8d48988d104941735','4d4b7105d754a06374d81259', '4bf58dd8d48988d1fa931735', '4bf58dd8d48988d1fd941735', '4bf58dd8d48988d10f951735', 
             '4bf58dd8d48988d1fd931735', '4bf58dd8d48988d129951735', '52f2ab2ebcbc57f1066b8b56', '4bf58dd8d48988d124941735','4bf58dd8d48988d1fe931735',
             '4bf58dd8d48988d10a951735', '50be8ee891d4fa8dcc7199a7','4bf58dd8d48988d12e941735', '4bf58dd8d48988d13b941735', '4d4b7105d754a06372d81259',
             '4bf58dd8d48988d163941735']
# Out:
#   File "<ipython-input-57-491cfaf20868>", line 2
#     'Metro Station', 'Train Station', 'ATM', 'Office', 'Bus Station', 'Bank', 'Market' ,
#     ^
# IndentationError: unexpected indent

# %%
from pandas.io.json import json_normalize
radius = 500
VERSION = 20180604
# Quality Infrastructure 
search_query2 = 'Park'
categoryId = '4bf58dd8d48988d163941735'
LIMIT = 1

# %%
def getNearbyVenues(names, lat1, long1, radius):
    venues_list=[]
    for name, lat, lng in zip(names, lat1, long1):

        # create the API request URL
        url1 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}&locale={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, search_query2, radius, LIMIT,  'en', categoryId)
        # make the GET request
        results = requests.get(url1).json()["response"]["venues"]
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['name'], 
            v['location']['lat'], 
            v['location']['lng'],
            v['categories'][0]['name']) for v in results])

        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])

    return(nearby_venues)

# %%
names=clean_df['Post Office']
latitudes=clean_df['Latitude']
longitudes=clean_df['Longitude']
all_venues = getNearbyVenues(names,latitudes, longitudes, radius )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-ef602318afa7> in <module>
# ----> 1 names=clean_df['Post Office']
#       2 latitudes=clean_df['Latitude']
#       3 longitudes=clean_df['Longitude']
#       4 all_venues = getNearbyVenues(names,latitudes, longitudes, radius )
#
# NameError: name 'clean_df' is not defined

# %%
all_venues.columns = ['Post Office','Latitude', 'Longitude','VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']

print(all_venues.shape)
all_venues.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-46f8f5d922a5> in <module>
# ----> 1 all_venues.columns = ['Post Office','Latitude', 'Longitude','VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']
#       2
#       3 print(all_venues.shape)
#       4 all_venues.head()
#
# NameError: name 'all_venues' is not defined

# %%
quality_infra_mumbai = all_venues.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-2d1c6b34f2d4> in <module>
# ----> 1 quality_infra_mumbai = all_venues.copy()
#
# NameError: name 'all_venues' is not defined

# %%
quality_infra_mumbai2 = quality_infra_mumbai2.append(quality_infra_mumbai, ignore_index = True)
quality_infra_mumbai2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-2f4a22c87434> in <module>
# ----> 1 quality_infra_mumbai2 = quality_infra_mumbai2.append(quality_infra_mumbai, ignore_index = True)
#       2 quality_infra_mumbai2.shape
#
# NameError: name 'quality_infra_mumbai2' is not defined

# %%
quality_infra_mumbai2.tail(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-6b7744504b88> in <module>
# ----> 1 quality_infra_mumbai2.tail(30)
#
# NameError: name 'quality_infra_mumbai2' is not defined

# %%
quality_infra_mumbai2.to_csv('essentialinfra.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-ba9ffb9b0f6d> in <module>
# ----> 1 quality_infra_mumbai2.to_csv('essentialinfra.csv')
#
# NameError: name 'quality_infra_mumbai2' is not defined

# %% [markdown]
# <h3>Clustering the dataset:</h3>

# %%
quality_infra_mumbai2['VenueCategory'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-0d42c0539ac7> in <module>
# ----> 1 quality_infra_mumbai2['VenueCategory'].unique()
#
# NameError: name 'quality_infra_mumbai2' is not defined

# %%
quality_mumbai_onehot = pd.get_dummies(quality_infra_mumbai2[['VenueCategory']], prefix="", prefix_sep="")

# add postal, borough and neighborhood column back to dataframe
quality_mumbai_onehot['Post Office'] = quality_infra_mumbai2['Post Office'] 

# move postal, borough and neighborhood column to the first column
fixed_columns = list(quality_mumbai_onehot.columns[-1:]) + list(quality_mumbai_onehot.columns[:-1])
quality_mumbai_onehot = quality_mumbai_onehot[fixed_columns]

print(quality_mumbai_onehot.shape)
quality_mumbai_onehot.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-10e85a566a80> in <module>
# ----> 1 quality_mumbai_onehot = pd.get_dummies(quality_infra_mumbai2[['VenueCategory']], prefix="", prefix_sep="")
#       2
#       3 # add postal, borough and neighborhood column back to dataframe
#       4 quality_mumbai_onehot['Post Office'] = quality_infra_mumbai2['Post Office']
#       5
#
# NameError: name 'pd' is not defined

# %%
qualitymumbai_grouped = quality_mumbai_onehot.groupby(["Post Office"]).sum().reset_index()

print(qualitymumbai_grouped.shape)
qualitymumbai_grouped.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-c53fd3c9fd95> in <module>
# ----> 1 qualitymumbai_grouped = quality_mumbai_onehot.groupby(["Post Office"]).sum().reset_index()
#       2
#       3 print(qualitymumbai_grouped.shape)
#       4 qualitymumbai_grouped.head()
#
# NameError: name 'quality_mumbai_onehot' is not defined

# %%
qualitymumbai_grouped['Total infrastructure'] =  qualitymumbai_grouped[qualitymumbai_grouped.drop(['Post Office'], axis=1).columns.values].sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-8d2ef53f16e1> in <module>
# ----> 1 qualitymumbai_grouped['Total infrastructure'] =  qualitymumbai_grouped[qualitymumbai_grouped.drop(['Post Office'], axis=1).columns.values].sum(axis=1)
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %%
qualitymumbai_groupedmax = qualitymumbai_grouped[qualitymumbai_grouped['Total infrastructure'] == qualitymumbai_grouped['Total infrastructure'].max()]
print("Best place to stay within a city for vital infrastructure facilities :")
qualitymumbai_groupedmax[['Post Office', 'Total infrastructure']]
print(qualitymumbai_groupedmax.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-316dac6b2c5b> in <module>
# ----> 1 qualitymumbai_groupedmax = qualitymumbai_grouped[qualitymumbai_grouped['Total infrastructure'] == qualitymumbai_grouped['Total infrastructure'].max()]
#       2 print("Best place to stay within a city for vital infrastructure facilities :")
#       3 qualitymumbai_groupedmax[['Post Office', 'Total infrastructure']]
#       4 print(qualitymumbai_groupedmax.shape)
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %%
mumbai_merged2 = qualitymumbai_grouped.copy()
mumbai_merged2 = mumbai_merged2.join(clean_df[["Pin Code",'Latitude', 'Longitude', "Post Office" ]].set_index("Post Office"), on="Post Office")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-73fe9583a932> in <module>
# ----> 1 mumbai_merged2 = qualitymumbai_grouped.copy()
#       2 mumbai_merged2 = mumbai_merged2.join(clean_df[["Pin Code",'Latitude', 'Longitude', "Post Office" ]].set_index("Post Office"), on="Post Office")
#
# NameError: name 'qualitymumbai_grouped' is not defined

# %%
fixed_columns = list(mumbai_merged2.columns[-3:]) + list(mumbai_merged2.columns[:-3])
mumbai_merged2 = mumbai_merged2[fixed_columns]

print(mumbai_merged2.shape)
mumbai_merged2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-c3e181fde2b8> in <module>
# ----> 1 fixed_columns = list(mumbai_merged2.columns[-3:]) + list(mumbai_merged2.columns[:-3])
#       2 mumbai_merged2 = mumbai_merged2[fixed_columns]
#       3
#       4 print(mumbai_merged2.shape)
#       5 mumbai_merged2.head()
#
# NameError: name 'mumbai_merged2' is not defined

# %%
kclusters = 3

mumbai_2_grouped_clustering = mumbai_merged2[["Total infrastructure"]]

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(mumbai_2_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-be5a88dded04> in <module>
#       1 kclusters = 3
#       2
# ----> 3 mumbai_2_grouped_clustering = mumbai_merged2[["Total infrastructure"]]
#       4
#       5 # run k-means clustering
#
# NameError: name 'mumbai_merged2' is not defined

# %%
mumbai_mergedfinal = mumbai_merged2.copy()
# add clustering labels
mumbai_mergedfinal["Cluster Labels"] = kmeans.labels_
print(mumbai_mergedfinal.shape)
mumbai_mergedfinal.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-ca18ebf70416> in <module>
# ----> 1 mumbai_mergedfinal = mumbai_merged2.copy()
#       2 # add clustering labels
#       3 mumbai_mergedfinal["Cluster Labels"] = kmeans.labels_
#       4 print(mumbai_mergedfinal.shape)
#       5 mumbai_mergedfinal.head()
#
# NameError: name 'mumbai_merged2' is not defined

# %% [markdown]
# <h3>Another round of visualization:</h3>

# %%
address = 'Mumbai'
latitude = 19.0760
longitude = 72.8777
print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geograpical coordinate of Mumbai are 19.076, 72.8777.

# %%
map_clusters  = folium.Map(location=[latitude, longitude], zoom_start=11)
# set color scheme for the clusters
x = np.arange(kclusters)
rainbow = [    'red',    'blue',    'orange',    'darkgreen',    'darkblue',    'black']
# add markers to map
markers_colors = []
for lat, lng, label1,common, cluster in zip(mumbai_mergedfinal['Latitude'], mumbai_mergedfinal['Longitude'], mumbai_mergedfinal['Post Office'],mumbai_mergedfinal['Total infrastructure'] , mumbai_mergedfinal['Cluster Labels']):
    labelnew =  'Post office : {} , Total infrastructure : {}'.format(label1,common)
    label = folium.Popup( labelnew, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_clusters)
map_clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-117979813fe6> in <module>
# ----> 1 map_clusters  = folium.Map(location=[latitude, longitude], zoom_start=11)
#       2 # set color scheme for the clusters
#       3 x = np.arange(kclusters)
#       4 rainbow = [    'red',    'blue',    'orange',    'darkgreen',    'darkblue',    'black']
#       5 # add markers to map
#
# NameError: name 'folium' is not defined

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://raw.githubusercontent.com/RohitLearner/IBM-Applied-D.S-Capstone-Project/master/Week%205/Results/Result_7.png")
# Out:
# <img src="https://raw.githubusercontent.com/RohitLearner/IBM-Applied-D.S-Capstone-Project/master/Week%205/Results/Result_7.png"/>

# %% [markdown]
# <h3>Clusters results:</h3>

# %% [markdown]
# <strong>Cluster 0:</strong>

# %%
mumbai_mergedfinal.loc[mumbai_mergedfinal['Cluster Labels'] == 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-e942910f4518> in <module>
# ----> 1 mumbai_mergedfinal.loc[mumbai_mergedfinal['Cluster Labels'] == 0]
#
# NameError: name 'mumbai_mergedfinal' is not defined

# %% [markdown]
# <strong>Cluster 1:</strong>

# %%
mumbai_mergedfinal.loc[mumbai_mergedfinal['Cluster Labels'] == 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-4f20b84e9122> in <module>
# ----> 1 mumbai_mergedfinal.loc[mumbai_mergedfinal['Cluster Labels'] == 1]
#
# NameError: name 'mumbai_mergedfinal' is not defined

# %% [markdown]
# <strong>Cluster 2:</strong>

# %%
mumbai_mergedfinal.loc[mumbai_mergedfinal['Cluster Labels'] == 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-94bff89267ea> in <module>
# ----> 1 mumbai_mergedfinal.loc[mumbai_mergedfinal['Cluster Labels'] == 2]
#
# NameError: name 'mumbai_mergedfinal' is not defined

# %% [markdown]
# <h3>Observations:</h3>

# %% [markdown]
# Most of the infrastructures are concentrated in the Southern areas of Mumbai city, with the highest number in cluster 0 and moderate number in cluster 2. On the other hand, cluster 1 has a very low number of infrastructures in the neighborhoods. This represents a great opportunity and high potential areas to open new infrastructures as it is very little to no competition from existing varied infrastructures. Meanwhile, one can specifically check the infrastructure of choice against the postal office choice area.
#
# A person who is planning to build infrastructure with unique selling propositions and lives prosperously to stand out from the competition can also open new infrastructures in neighborhoods in cluster 2 with moderate competition and supporting adequate no. of infrastructures. Lastly, people with planning to settle in the city are advised to start in cluster 0 which already has a high concentration of infrastructures.

# %% [markdown]
# <h3>Acknowledgement:</h3>

# %% [markdown]
# In this project, I have gone through the process of identifying the business problems, specifying the data required, extracting and preparing the data, visualizing the results, performing machine learning by clustering the data into 3 clusters based on their frequency similarities, tackling and reaching to a definitive solution to business problems (mentioned in results). Lastly, the project is providing recommendations to the relevant stakeholders i.e. business developers regarding the best locations to open a new infrastructure. The project also provides visitors and immigrants to the city regarding postal office areas for growth and living prosperously.

# %% [markdown]
# <h3>Links to other assets of the project:</h3>

# %% [markdown]
# Report link:
# Presentation link:
#
# Thanks and have a nice day!
